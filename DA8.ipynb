# %% [markdown]
# <a href="https://colab.research.google.com/github/kastrahl/Data-science/blob/main/DA8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#necessary libraries 
import numpy as np
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
retdata = pd.read_csv('https://raw.githubusercontent.com/kastrahl/Data-science/main/MBA.csv', header = None)
retdata.head()
# Out:
#               0          1           2                 3             4   \
# 0         shrimp    almonds     avocado    vegetables mix  green grapes
# 1        burgers  meatballs        eggs               NaN           NaN
# 2        chutney        NaN         NaN               NaN           NaN
# 3         turkey    avocado         NaN               NaN           NaN
# 4  mineral water       milk  energy bar  whole wheat rice     green tea
#
#                  5     6               7             8             9   \
# 0  whole weat flour  yams  cottage cheese  energy drink  tomato juice
# 1               NaN   NaN             NaN           NaN           NaN
# 2               NaN   NaN             NaN           NaN           NaN
# 3               NaN   NaN             NaN           NaN           NaN
# 4               NaN   NaN             NaN           NaN           NaN
#
#                10         11     12     13             14      15  \
# ...

# %%
#Transforming the list into a list of lists, so that each transaction can be indexed easier
transactions = []
for i in range(0, retdata.shape[0]):
    transactions.append([str(retdata.values[i, j]) for j in range(0, 20)])
print(transactions[0])
# Out:
# ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes', 'whole weat flour', 'yams', 'cottage cheese', 'energy drink', 'tomato juice', 'low fat yogurt', 'green tea', 'honey', 'salad', 'mineral water', 'salmon', 'antioxydant juice', 'frozen smoothie', 'spinach', 'olive oil']

# %%
! pip install apyori
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for apyori: filename=apyori-1.1.2-py3-none-any.whl size=5974 sha256=f8e2b34583d43cc70d06e2bd5d55d1ad9f50c3ca5f54ca77ed9dfb048644ab54
#   Stored in directory: /root/.cache/pip/wheels/cb/f6/e1/57973c631d27efd1a2f375bd6a83b2a616c4021f24aab84080
# Successfully built apyori
# ...

# %%
from apyori import apriori
rules = apriori(transactions, min_support = 0.003, min_confidence = 0.2, min_lift = 3, min_length = 2)
# Support: number of transactions containing set of times / total number of transactions
# Confidence: Should not be too high, as then this wil lead to obvious rules
results = list(rules)

# %%
results = pd.DataFrame(results)
results.head(5)
# Out:
#                               items   support  \
# 0            (chicken, light cream)  0.004533
# 1  (escalope, mushroom cream sauce)  0.005733
# 2                 (pasta, escalope)  0.005866
# 3            (honey, fromage blanc)  0.003333
# 4      (ground beef, herb & pepper)  0.015998
#
#                                   ordered_statistics
# 0  [((light cream), (chicken), 0.2905982905982905...
# 1  [((mushroom cream sauce), (escalope), 0.300699...
# 2  [((pasta), (escalope), 0.3728813559322034, 4.7...
# 3  [((fromage blanc), (honey), 0.2450980392156863...
# 4  [((herb & pepper), (ground beef), 0.3234501347...
